# %%
import pandas as pd
import numpy as np
from sklearn.datasets import fetch_california_housing
import matplotlib.pyplot as plt
from pandas.plotting import scatter_matrix
from sklearn.metrics import r2_score
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_squared_error

# %%
dataset = fetch_california_housing()
print(dataset.DESCR)
# Out:
# .. _california_housing_dataset:
#
# California Housing dataset
# --------------------------
#
# **Data Set Characteristics:**
#
#     :Number of Instances: 20640
#
#     :Number of Attributes: 8 numeric, predictive attributes and the target
#
#     :Attribute Information:
#         - MedInc        median income in block group
#         - HouseAge      median house age in block group
#         - AveRooms      average number of rooms per household
#         - AveBedrms     average number of bedrooms per household
#         - Population    block group population
#         - AveOccup      average number of household members
#         - Latitude      block group latitude
#         - Longitude     block group longitude
#
#     :Missing Attribute Values: None
#
# This dataset was obtained from the StatLib repository.
# https://www.dcc.fc.up.pt/~ltorgo/Regression/cal_housing.html
#
# The target variable is the median house value for California districts,
# ...

# %% [markdown]
# ## #1 Medinc to target

# %%
x= dataset['data'][...,0:1]
y= dataset['target']
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = 0.2)
model = LinearRegression()
model.fit(x_train, y_train)
y_pred = model.predict(x_test)
w = model.coef_
b = model.intercept_
r2 = r2_score(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
print('Train test split=', x_train.shape,x_test.shape)
print('R2_SCORE=',r2,'Mean_squared_error=',mse)
# Out:
# Train test split= (16512, 1) (4128, 1)
# R2_SCORE= 0.4787764688875117 Mean_squared_error= 0.7119460036734202

# %% [markdown]
# ## #2 House age to target

# %%
x= dataset['data'][...,1:2]
y= dataset['target']
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = 0.2)
model = LinearRegression()
model.fit(x_train, y_train)
y_pred = model.predict(x_test)
w = model.coef_
b = model.intercept_
r2 = r2_score(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
print('Train test split=', x_train.shape,x_test.shape)
print('R2_SCORE=',r2,'Mean_squared_error=',mse)
# Out:
# Train test split= (16512, 1) (4128, 1)
# R2_SCORE= 0.008063691247427562 Mean_squared_error= 1.347064687426325

# %% [markdown]
# ## #3 Average rooms to target

# %%
x= dataset['data'][...,2:3]
y= dataset['target']
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = 0.2)
model = LinearRegression()
model.fit(x_train, y_train)
y_pred = model.predict(x_test)
w = model.coef_
b = model.intercept_
r2 = r2_score(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
print('Train test split=', x_train.shape,x_test.shape)
print('R2_SCORE=',r2,'Mean_squared_error=',mse)
# Out:
# Train test split= (16512, 1) (4128, 1)
# R2_SCORE= 0.013823867425385772 Mean_squared_error= 1.2527629646710654

# %% [markdown]
# ## #4 Average bedrooms to target

# %%
x= dataset['data'][...,3:4]
y= dataset['target']
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = 0.2)
model = LinearRegression()
model.fit(x_train, y_train)
y_pred = model.predict(x_test)
w = model.coef_
b = model.intercept_
r2 = r2_score(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
print('Train test split=', x_train.shape,x_test.shape)
print('R2_SCORE=',r2,'Mean_squared_error=',mse)
# Out:
# Train test split= (16512, 1) (4128, 1)
# R2_SCORE= 0.003135870943248298 Mean_squared_error= 1.318920445376758

# %% [markdown]
# ## #5 population to target

# %%
x= dataset['data'][...,4:5]
y= dataset['target']
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = 0.2)
model = LinearRegression()
model.fit(x_train, y_train)
y_pred = model.predict(x_test)
w = model.coef_
b = model.intercept_
r2 = r2_score(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
print('Train test split=', x_train.shape,x_test.shape)
print('R2_SCORE=',r2,'Mean_squared_error=',mse)
# Out:
# Train test split= (16512, 1) (4128, 1)
# R2_SCORE= 4.1126617957853995e-05 Mean_squared_error= 1.3291154073497142

# %% [markdown]
# ## #6 Average occu. to target

# %%
x= dataset['data'][...,5:6]
y= dataset['target']
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = 0.2)
model = LinearRegression()
model.fit(x_train, y_train)
y_pred = model.predict(x_test)
w = model.coef_
b = model.intercept_
r2 = r2_score(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
print('Train test split=', x_train.shape,x_test.shape)
print('R2_SCORE=',r2,'Mean_squared_error=',mse)
# Out:
# Train test split= (16512, 1) (4128, 1)
# R2_SCORE= 0.0001562216207859901 Mean_squared_error= 1.3022950418421284

# %% [markdown]
# ## #7 Latitude to target

# %%
x= dataset['data'][...,6:7]
y= dataset['target']
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = 0.2)
model = LinearRegression()
model.fit(x_train, y_train)
y_pred = model.predict(x_test)
w = model.coef_
b = model.intercept_
r2 = r2_score(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
print('Train test split=', x_train.shape,x_test.shape)
print('R2_SCORE=',r2,'Mean_squared_error=',mse)
# Out:
# Train test split= (16512, 1) (4128, 1)
# R2_SCORE= 0.019516178823327013 Mean_squared_error= 1.268348572321709

# %% [markdown]
# ## #8 Longitude to target

# %%
x= dataset['data'][...,7:8]
y= dataset['target']
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = 0.2)
model = LinearRegression()
model.fit(x_train, y_train)
y_pred = model.predict(x_test)
w = model.coef_
b = model.intercept_
r2 = r2_score(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
print('Train test split=', x_train.shape,x_test.shape)
print('R2_SCORE=',r2,'Mean_squared_error=',mse)
# Out:
# Train test split= (16512, 1) (4128, 1)
# R2_SCORE= 0.0011107540902428603 Mean_squared_error= 1.316454428767967

# %% [markdown]
# ## Final Results for R2 Score and Mean squared error

# %%
x= dataset['data']
y= dataset['target']
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = 0.2)
model = LinearRegression()
model.fit(x_train, y_train)
y_pred = model.predict(x_test)
w = model.coef_
b = model.intercept_
r2 = r2_score(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
print('Train test split=', x_train.shape,x_test.shape)
print('R2_SCORE=',r2,'Mean_squared_error=',mse)
# Out:
# Train test split= (16512, 8) (4128, 8)
# R2_SCORE= 0.6147739375511112 Mean_squared_error= 0.5210428192301788

# %% [markdown]
# ## Graphs and Figures

# %%
plt.scatter(x[...,0], y)
plt.xlabel('MedInc')
plt.ylabel('Housing Prices')
# Out:
# Text(0, 0.5, 'Housing Prices')

# %%
dataset = fetch_california_housing(as_frame=True)
dataset = dataset.frame
dataset.head()
dataset.plot(kind="scatter", x="Longitude",y="Latitude", c="MedHouseVal", cmap="jet", colorbar=True, legend=True, sharex=False, figsize=(10,7), s=dataset['Population']/100, label="population", alpha=0.7)
plt.show()
